# %%
import json

# %%
x = json.loads('[{"1stFlrSF": 896, "2ndFlrSF": 0, "3SsnPorch": 0, "Alley": null, "BedroomAbvGr": 2, "BldgType": "1Fam", "BsmtCond": "TA", "BsmtExposure": "No", "BsmtFinSF1": 468.0, "BsmtFinSF2": 144.0, "BsmtFinType1": "Rec", "BsmtFinType2": "LwQ", "BsmtFullBath": 0.0, "BsmtHalfBath": 0.0, "BsmtQual": "TA", "BsmtUnfSF": 270.0, "CentralAir": "Y", "Condition1": "Feedr", "Condition2": "Norm", "Electrical": "SBrkr", "EnclosedPorch": 0, "ExterCond": "TA", "ExterQual": "TA", "Exterior1st": "VinylSd", "Exterior2nd": "VinylSd", "Fence": "MnPrv", "FireplaceQu": null, "Fireplaces": 0, "Foundation": "CBlock", "FullBath": 1, "Functional": "Typ", "GarageArea": 730.0, "GarageCars": 1.0, "GarageCond": "TA", "GarageFinish": "Unf", "GarageQual": "TA", "GarageType": "Attchd", "GarageYrBlt": 1961.0, "GrLivArea": 896, "HalfBath": 0, "Heating": "GasA", "HeatingQC": "TA", "HouseStyle": "1Story", "Id": 1461, "KitchenAbvGr": 1, "KitchenQual": "TA", "LandContour": "Lvl", "LandSlope": "Gtl", "LotArea": 11622, "LotConfig": "Inside", "LotFrontage": 80.0, "LotShape": "Reg", "LowQualFinSF": 0, "MSSubClass": 20, "MSZoning": "RH", "MasVnrArea": 0.0, "MasVnrType": "None", "MiscFeature": null, "MiscVal": 0, "MoSold": 6, "Neighborhood": "NAmes", "OpenPorchSF": 0, "OverallCond": 6, "OverallQual": 5, "PavedDrive": "Y", "PoolArea": 0, "PoolQC": null, "RoofMatl": "CompShg", "RoofStyle": "Gable", "SaleCondition": "Normal", "SaleType": "WD", "ScreenPorch": 120, "Street": "Pave", "TotRmsAbvGrd": 5, "TotalBsmtSF": 882.0, "Utilities": "AllPub", "WoodDeckSF": 140, "YearBuilt": 1961, "YearRemodAdd": 1961, "YrSold": 2010}]')
x
# Out:
# [{'1stFlrSF': 896,
#   '2ndFlrSF': 0,
#   '3SsnPorch': 0,
#   'Alley': None,
#   'BedroomAbvGr': 2,
#   'BldgType': '1Fam',
#   'BsmtCond': 'TA',
#   'BsmtExposure': 'No',
#   'BsmtFinSF1': 468.0,
#   'BsmtFinSF2': 144.0,
#   'BsmtFinType1': 'Rec',
#   'BsmtFinType2': 'LwQ',
#   'BsmtFullBath': 0.0,
#   'BsmtHalfBath': 0.0,
#   'BsmtQual': 'TA',
#   'BsmtUnfSF': 270.0,
#   'CentralAir': 'Y',
#   'Condition1': 'Feedr',
#   'Condition2': 'Norm',
#   'Electrical': 'SBrkr',
#   'EnclosedPorch': 0,
#   'ExterCond': 'TA',
#   'ExterQual': 'TA',
#   'Exterior1st': 'VinylSd',
#   'Exterior2nd': 'VinylSd',
#   'Fence': 'MnPrv',
#   'FireplaceQu': None,
#   'Fireplaces': 0,
#   'Foundation': 'CBlock',
#   'FullBath': 1,
#   'Functional': 'Typ',
#   'GarageArea': 730.0,
#   'GarageCars': 1.0,
#   'GarageCond': 'TA',
#   'GarageFinish': 'Unf',
#   'GarageQual': 'TA',
#   'GarageType': 'Attchd',
#   'GarageYrBlt': 1961.0,
#   'GrLivArea': 896,
#   'HalfBath': 0,
#   'Heating': 'GasA',
#   'HeatingQC': 'TA',
#   'HouseStyle': '1Story',
#   'Id': 1461,
#   'KitchenAbvGr': 1,
#   'KitchenQual': 'TA',
#   'LandContour': 'Lvl',
#   'LandSlope': 'Gtl',
#   'LotArea': 11622,
#   'LotConfig': 'Inside',
#   'LotFrontage': 80.0,
#   'LotShape': 'Reg',
#   'LowQualFinSF': 0,
#   'MSSubClass': 20,
#   'MSZoning': 'RH',
#   'MasVnrArea': 0.0,
#   'MasVnrType': 'None',
#   'MiscFeature': None,
#   'MiscVal': 0,
#   'MoSold': 6,
#   'Neighborhood': 'NAmes',
#   'OpenPorchSF': 0,
#   'OverallCond': 6,
#   'OverallQual': 5,
#   'PavedDrive': 'Y',
#   'PoolArea': 0,
#   'PoolQC': None,
#   'RoofMatl': 'CompShg',
#   'RoofStyle': 'Gable',
#   'SaleCondition': 'Normal',
#   'SaleType': 'WD',
#   'ScreenPorch': 120,
#   'Street': 'Pave',
#   'TotRmsAbvGrd': 5,
#   'TotalBsmtSF': 882.0,
#   'Utilities': 'AllPub',
#   'WoodDeckSF': 140,
#   'YearBuilt': 1961,
#   'YearRemodAdd': 1961,
#   'YrSold': 2010}]

# %%
SYNTAX_ERROR_FIELD_MAP = {
    '1stFlrSF': 'FirstFlrSF',
    '2ndFlrSF': 'SecondFlrSF',
    '3SsnPorch': 'ThreeSsnPortch'
}
SYNTAX_ERROR_FIELD_MAP
# Out:
# {'1stFlrSF': 'FirstFlrSF',
#  '2ndFlrSF': 'SecondFlrSF',
#  '3SsnPorch': 'ThreeSsnPortch'}

# %%
x[0].keys()
# Out:
# dict_keys(['1stFlrSF', '2ndFlrSF', '3SsnPorch', 'Alley', 'BedroomAbvGr', 'BldgType', 'BsmtCond', 'BsmtExposure', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtFinType1', 'BsmtFinType2', 'BsmtFullBath', 'BsmtHalfBath', 'BsmtQual', 'BsmtUnfSF', 'CentralAir', 'Condition1', 'Condition2', 'Electrical', 'EnclosedPorch', 'ExterCond', 'ExterQual', 'Exterior1st', 'Exterior2nd', 'Fence', 'FireplaceQu', 'Fireplaces', 'Foundation', 'FullBath', 'Functional', 'GarageArea', 'GarageCars', 'GarageCond', 'GarageFinish', 'GarageQual', 'GarageType', 'GarageYrBlt', 'GrLivArea', 'HalfBath', 'Heating', 'HeatingQC', 'HouseStyle', 'Id', 'KitchenAbvGr', 'KitchenQual', 'LandContour', 'LandSlope', 'LotArea', 'LotConfig', 'LotFrontage', 'LotShape', 'LowQualFinSF', 'MSSubClass', 'MSZoning', 'MasVnrArea', 'MasVnrType', 'MiscFeature', 'MiscVal', 'MoSold', 'Neighborhood', 'OpenPorchSF', 'OverallCond', 'OverallQual', 'PavedDrive', 'PoolArea', 'PoolQC', 'RoofMatl', 'RoofStyle', 'SaleCondition', 'SaleType', 'ScreenPorch', 'Street', 'TotRmsAbvGrd', 'TotalBsmtSF', 'Utilities', 'WoodDeckSF', 'YearBuilt', 'YearRemodAdd', 'YrSold'])

# %%
x[0]["1stFlrSF"]
# Out:
# 896

# %%
a_dict = {'color': 'blue', 'fruit': 'apple', 'pet': 'dog'}
for key in a_dict:
    print(key)
# Out:
# color
# fruit
# pet

# %%
import pandas as pd
y = pd.read_json('[{"1stFlrSF": 444, "2ndFlrSF": 99, "3SsnPorch": 787, "Alley": null, "BedroomAbvGr": 2, "BldgType": "1Fam", "BsmtCond": "TA", "BsmtExposure": "No", "BsmtFinSF1": 468.0, "BsmtFinSF2": 144.0, "BsmtFinType1": "Rec", "BsmtFinType2": "LwQ", "BsmtFullBath": 0.0, "BsmtHalfBath": 0.0, "BsmtQual": "TA", "BsmtUnfSF": 270.0, "CentralAir": "Y", "Condition1": "Feedr", "Condition2": "Norm", "Electrical": "SBrkr", "EnclosedPorch": 0, "ExterCond": "TA", "ExterQual": "TA", "Exterior1st": "VinylSd", "Exterior2nd": "VinylSd", "Fence": "MnPrv", "FireplaceQu": null, "Fireplaces": 0, "Foundation": "CBlock", "FullBath": 1, "Functional": "Typ", "GarageArea": 730.0, "GarageCars": 1.0, "GarageCond": "TA", "GarageFinish": "Unf", "GarageQual": "TA", "GarageType": "Attchd", "GarageYrBlt": 1961.0, "GrLivArea": 896, "HalfBath": 0, "Heating": "GasA", "HeatingQC": "TA", "HouseStyle": "1Story", "Id": 1461, "KitchenAbvGr": 1, "KitchenQual": "TA", "LandContour": "Lvl", "LandSlope": "Gtl", "LotArea": 11622, "LotConfig": "Inside", "LotFrontage": 80.0, "LotShape": "Reg", "LowQualFinSF": 0, "MSSubClass": 20, "MSZoning": "RH", "MasVnrArea": 0.0, "MasVnrType": "None", "MiscFeature": null, "MiscVal": 0, "MoSold": 6, "Neighborhood": "NAmes", "OpenPorchSF": 0, "OverallCond": 6, "OverallQual": 5, "PavedDrive": "Y", "PoolArea": 0, "PoolQC": null, "RoofMatl": "CompShg", "RoofStyle": "Gable", "SaleCondition": "Normal", "SaleType": "WD", "ScreenPorch": 120, "Street": "Pave", "TotRmsAbvGrd": 5, "TotalBsmtSF": 882.0, "Utilities": "AllPub", "WoodDeckSF": 140, "YearBuilt": 1961, "YearRemodAdd": 1961, "YrSold": 2010},{"1stFlrSF": 896, "2ndFlrSF": 0, "3SsnPorch": 0, "Alley": null, "BedroomAbvGr": 2, "BldgType": "1Fam", "BsmtCond": "TA", "BsmtExposure": "No", "BsmtFinSF1": 468.0, "BsmtFinSF2": 144.0, "BsmtFinType1": "Rec", "BsmtFinType2": "LwQ", "BsmtFullBath": 0.0, "BsmtHalfBath": 0.0, "BsmtQual": "TA", "BsmtUnfSF": 270.0, "CentralAir": "Y", "Condition1": "Feedr", "Condition2": "Norm", "Electrical": "SBrkr", "EnclosedPorch": 0, "ExterCond": "TA", "ExterQual": "TA", "Exterior1st": "VinylSd", "Exterior2nd": "VinylSd", "Fence": "MnPrv", "FireplaceQu": null, "Fireplaces": 0, "Foundation": "CBlock", "FullBath": 1, "Functional": "Typ", "GarageArea": 730.0, "GarageCars": 1.0, "GarageCond": "TA", "GarageFinish": "Unf", "GarageQual": "TA", "GarageType": "Attchd", "GarageYrBlt": 1961.0, "GrLivArea": 896, "HalfBath": 0, "Heating": "GasA", "HeatingQC": "TA", "HouseStyle": "1Story", "Id": 1461, "KitchenAbvGr": 1, "KitchenQual": "TA", "LandContour": "Lvl", "LandSlope": "Gtl", "LotArea": 11622, "LotConfig": "Inside", "LotFrontage": 80.0, "LotShape": "Reg", "LowQualFinSF": 0, "MSSubClass": 20, "MSZoning": "RH", "MasVnrArea": 0.0, "MasVnrType": "None", "MiscFeature": null, "MiscVal": 0, "MoSold": 6, "Neighborhood": "NAmes", "OpenPorchSF": 0, "OverallCond": 6, "OverallQual": 5, "PavedDrive": "Y", "PoolArea": 0, "PoolQC": null, "RoofMatl": "CompShg", "RoofStyle": "Gable", "SaleCondition": "Normal", "SaleType": "WD", "ScreenPorch": 120, "Street": "Pave", "TotRmsAbvGrd": 5, "TotalBsmtSF": 882.0, "Utilities": "AllPub", "WoodDeckSF": 140, "YearBuilt": 1961, "YearRemodAdd": 1961, "YrSold": 2010}]')
y
# Out:
#    1stFlrSF  2ndFlrSF  3SsnPorch  Alley  BedroomAbvGr BldgType BsmtCond  \
# 0       444        99        787    NaN             2     1Fam       TA
# 1       896         0          0    NaN             2     1Fam       TA
#
#   BsmtExposure  BsmtFinSF1  BsmtFinSF2  ... SaleType ScreenPorch  Street  \
# 0           No         468         144  ...       WD         120    Pave
# 1           No         468         144  ...       WD         120    Pave
#
#    TotRmsAbvGrd TotalBsmtSF  Utilities WoodDeckSF YearBuilt YearRemodAdd  \
# 0             5         882     AllPub        140      1961         1961
# 1             5         882     AllPub        140      1961         1961
#
#   YrSold
# 0   2010
# 1   2010
#
# [2 rows x 80 columns]

# %%
for d in y:
    for key, value in SYNTAX_ERROR_FIELD_MAP.items():
        if(d == key):
            y[value] = y[key] 
            del y[key]

# %%
y
# Out:
#    Alley  BedroomAbvGr BldgType BsmtCond BsmtExposure  BsmtFinSF1  BsmtFinSF2  \
# 0    NaN             2     1Fam       TA           No         468         144
# 1    NaN             2     1Fam       TA           No         468         144
#
#   BsmtFinType1 BsmtFinType2  BsmtFullBath  ...  TotRmsAbvGrd TotalBsmtSF  \
# 0          Rec          LwQ             0  ...             5         882
# 1          Rec          LwQ             0  ...             5         882
#
#    Utilities WoodDeckSF YearBuilt YearRemodAdd YrSold  FirstFlrSF SecondFlrSF  \
# 0     AllPub        140      1961         1961   2010         444          99
# 1     AllPub        140      1961         1961   2010         896           0
#
#   ThreeSsnPortch
# 0            787
# 1              0
#
# [2 rows x 80 columns]

# %%
y.to_json(orient='records')
# Out:
# '[{"Alley":null,"BedroomAbvGr":2,"BldgType":"1Fam","BsmtCond":"TA","BsmtExposure":"No","BsmtFinSF1":468,"BsmtFinSF2":144,"BsmtFinType1":"Rec","BsmtFinType2":"LwQ","BsmtFullBath":0,"BsmtHalfBath":0,"BsmtQual":"TA","BsmtUnfSF":270,"CentralAir":"Y","Condition1":"Feedr","Condition2":"Norm","Electrical":"SBrkr","EnclosedPorch":0,"ExterCond":"TA","ExterQual":"TA","Exterior1st":"VinylSd","Exterior2nd":"VinylSd","Fence":"MnPrv","FireplaceQu":null,"Fireplaces":0,"Foundation":"CBlock","FullBath":1,"Functional":"Typ","GarageArea":730,"GarageCars":1,"GarageCond":"TA","GarageFinish":"Unf","GarageQual":"TA","GarageType":"Attchd","GarageYrBlt":1961,"GrLivArea":896,"HalfBath":0,"Heating":"GasA","HeatingQC":"TA","HouseStyle":"1Story","Id":1461,"KitchenAbvGr":1,"KitchenQual":"TA","LandContour":"Lvl","LandSlope":"Gtl","LotArea":11622,"LotConfig":"Inside","LotFrontage":80,"LotShape":"Reg","LowQualFinSF":0,"MSSubClass":20,"MSZoning":"RH","MasVnrArea":0,"MasVnrType":"None","MiscFeature":null,"MiscVal":0,"MoSold":6,"Neighborhood":"NAmes","OpenPorchSF":0,"OverallCond":6,"OverallQual":5,"PavedDrive":"Y","PoolArea":0,"PoolQC":null,"RoofMatl":"CompShg","RoofStyle":"Gable","SaleCondition":"Normal","SaleType":"WD","ScreenPorch":120,"Street":"Pave","TotRmsAbvGrd":5,"TotalBsmtSF":882,"Utilities":"AllPub","WoodDeckSF":140,"YearBuilt":1961,"YearRemodAdd":1961,"YrSold":2010,"FirstFlrSF":444,"SecondFlrSF":99,"ThreeSsnPortch":787},{"Alley":null,"BedroomAbvGr":2,"BldgType":"1Fam","BsmtCond":"TA","BsmtExposure":"No","BsmtFinSF1":468,"BsmtFinSF2":144,"BsmtFinType1":"Rec","BsmtFinType2":"LwQ","BsmtFullBath":0,"BsmtHalfBath":0,"BsmtQual":"TA","BsmtUnfSF":270,"CentralAir":"Y","Condition1":"Feedr","Condition2":"Norm","Electrical":"SBrkr","EnclosedPorch":0,"ExterCond":"TA","ExterQual":"TA","Exterior1st":"VinylSd","Exterior2nd":"VinylSd","Fence":"MnPrv","FireplaceQu":null,"Fireplaces":0,"Foundation":"CBlock","FullBath":1,"Functional":"Typ","GarageArea":730,"GarageCars":1,"GarageCond":"TA","GarageFinish":"Unf","GarageQual":"TA","GarageType":"Attchd","GarageYrBlt":1961,"GrLivArea":896,"HalfBath":0,"Heating":"GasA","HeatingQC":"TA","HouseStyle":"1Story","Id":1461,"KitchenAbvGr":1,"KitchenQual":"TA","LandContour":"Lvl","LandSlope":"Gtl","LotArea":11622,"LotConfig":"Inside","LotFrontage":80,"LotShape":"Reg","LowQualFinSF":0,"MSSubClass":20,"MSZoning":"RH","MasVnrArea":0,"MasVnrType":"None","MiscFeature":null,"MiscVal":0,"MoSold":6,"Neighborhood":"NAmes","OpenPorchSF":0,"OverallCond":6,"OverallQual":5,"PavedDrive":"Y","PoolArea":0,"PoolQC":null,"RoofMatl":"CompShg","RoofStyle":"Gable","SaleCondition":"Normal","SaleType":"WD","ScreenPorch":120,"Street":"Pave","TotRmsAbvGrd":5,"TotalBsmtSF":882,"Utilities":"AllPub","WoodDeckSF":140,"YearBuilt":1961,"YearRemodAdd":1961,"YrSold":2010,"FirstFlrSF":896,"SecondFlrSF":0,"ThreeSsnPortch":0}]'

# %%
# pd.read_json()
# pd.read_json(json.loads(y.to_json()))
json.dumps(json.loads(y.to_json()))

# type(json.loads(y.to_json()))
# Out:
# '{"Alley": {"0": null, "1": null}, "BedroomAbvGr": {"0": 2, "1": 2}, "BldgType": {"0": "1Fam", "1": "1Fam"}, "BsmtCond": {"0": "TA", "1": "TA"}, "BsmtExposure": {"0": "No", "1": "No"}, "BsmtFinSF1": {"0": 468, "1": 468}, "BsmtFinSF2": {"0": 144, "1": 144}, "BsmtFinType1": {"0": "Rec", "1": "Rec"}, "BsmtFinType2": {"0": "LwQ", "1": "LwQ"}, "BsmtFullBath": {"0": 0, "1": 0}, "BsmtHalfBath": {"0": 0, "1": 0}, "BsmtQual": {"0": "TA", "1": "TA"}, "BsmtUnfSF": {"0": 270, "1": 270}, "CentralAir": {"0": "Y", "1": "Y"}, "Condition1": {"0": "Feedr", "1": "Feedr"}, "Condition2": {"0": "Norm", "1": "Norm"}, "Electrical": {"0": "SBrkr", "1": "SBrkr"}, "EnclosedPorch": {"0": 0, "1": 0}, "ExterCond": {"0": "TA", "1": "TA"}, "ExterQual": {"0": "TA", "1": "TA"}, "Exterior1st": {"0": "VinylSd", "1": "VinylSd"}, "Exterior2nd": {"0": "VinylSd", "1": "VinylSd"}, "Fence": {"0": "MnPrv", "1": "MnPrv"}, "FireplaceQu": {"0": null, "1": null}, "Fireplaces": {"0": 0, "1": 0}, "Foundation": {"0": "CBlock", "1": "CBlock"}, "FullBath": {"0": 1, "1": 1}, "Functional": {"0": "Typ", "1": "Typ"}, "GarageArea": {"0": 730, "1": 730}, "GarageCars": {"0": 1, "1": 1}, "GarageCond": {"0": "TA", "1": "TA"}, "GarageFinish": {"0": "Unf", "1": "Unf"}, "GarageQual": {"0": "TA", "1": "TA"}, "GarageType": {"0": "Attchd", "1": "Attchd"}, "GarageYrBlt": {"0": 1961, "1": 1961}, "GrLivArea": {"0": 896, "1": 896}, "HalfBath": {"0": 0, "1": 0}, "Heating": {"0": "GasA", "1": "GasA"}, "HeatingQC": {"0": "TA", "1": "TA"}, "HouseStyle": {"0": "1Story", "1": "1Story"}, "Id": {"0": 1461, "1": 1461}, "KitchenAbvGr": {"0": 1, "1": 1}, "KitchenQual": {"0": "TA", "1": "TA"}, "LandContour": {"0": "Lvl", "1": "Lvl"}, "LandSlope": {"0": "Gtl", "1": "Gtl"}, "LotArea": {"0": 11622, "1": 11622}, "LotConfig": {"0": "Inside", "1": "Inside"}, "LotFrontage": {"0": 80, "1": 80}, "LotShape": {"0": "Reg", "1": "Reg"}, "LowQualFinSF": {"0": 0, "1": 0}, "MSSubClass": {"0": 20, "1": 20}, "MSZoning": {"0": "RH", "1": "RH"}, "MasVnrArea": {"0": 0, "1": 0}, "MasVnrType": {"0": "None", "1": "None"}, "MiscFeature": {"0": null, "1": null}, "MiscVal": {"0": 0, "1": 0}, "MoSold": {"0": 6, "1": 6}, "Neighborhood": {"0": "NAmes", "1": "NAmes"}, "OpenPorchSF": {"0": 0, "1": 0}, "OverallCond": {"0": 6, "1": 6}, "OverallQual": {"0": 5, "1": 5}, "PavedDrive": {"0": "Y", "1": "Y"}, "PoolArea": {"0": 0, "1": 0}, "PoolQC": {"0": null, "1": null}, "RoofMatl": {"0": "CompShg", "1": "CompShg"}, "RoofStyle": {"0": "Gable", "1": "Gable"}, "SaleCondition": {"0": "Normal", "1": "Normal"}, "SaleType": {"0": "WD", "1": "WD"}, "ScreenPorch": {"0": 120, "1": 120}, "Street": {"0": "Pave", "1": "Pave"}, "TotRmsAbvGrd": {"0": 5, "1": 5}, "TotalBsmtSF": {"0": 882, "1": 882}, "Utilities": {"0": "AllPub", "1": "AllPub"}, "WoodDeckSF": {"0": 140, "1": 140}, "YearBuilt": {"0": 1961, "1": 1961}, "YearRemodAdd": {"0": 1961, "1": 1961}, "YrSold": {"0": 2010, "1": 2010}, "FirstFlrSF": {"0": 444, "1": 896}, "SecondFlrSF": {"0": 99, "1": 0}, "ThreeSsnPortch": {"0": 787, "1": 0}}'

# %%
y2 = json.dumps(json.loads(y.to_json()))
y2 = pd.read_json(y2)
y2
# Out:
#    Alley  BedroomAbvGr BldgType BsmtCond BsmtExposure  BsmtFinSF1  BsmtFinSF2  \
# 0    NaN             2     1Fam       TA           No         468         144
# 1    NaN             2     1Fam       TA           No         468         144
#
#   BsmtFinType1 BsmtFinType2  BsmtFullBath  ...  TotRmsAbvGrd TotalBsmtSF  \
# 0          Rec          LwQ             0  ...             5         882
# 1          Rec          LwQ             0  ...             5         882
#
#    Utilities WoodDeckSF YearBuilt YearRemodAdd YrSold  FirstFlrSF SecondFlrSF  \
# 0     AllPub        140      1961         1961   2010         444          99
# 1     AllPub        140      1961         1961   2010         896           0
#
#   ThreeSsnPortch
# 0            787
# 1              0
#
# [2 rows x 80 columns]

# %%
for d in y2:
    for key, value in SYNTAX_ERROR_FIELD_MAP.items():
        if(d == value):
            y2[key] = y2[value] 
            del y2[value]
# Out:
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch
# key=1stFlrSF
# value=FirstFlrSF
# key=2ndFlrSF
# value=SecondFlrSF
# key=3SsnPorch
# value=ThreeSsnPortch

# %%
y2
# Out:
#    Alley  BedroomAbvGr BldgType BsmtCond BsmtExposure  BsmtFinSF1  BsmtFinSF2  \
# 0    NaN             2     1Fam       TA           No         468         144
# 1    NaN             2     1Fam       TA           No         468         144
#
#   BsmtFinType1 BsmtFinType2  BsmtFullBath  ...  TotRmsAbvGrd TotalBsmtSF  \
# 0          Rec          LwQ             0  ...             5         882
# 1          Rec          LwQ             0  ...             5         882
#
#    Utilities WoodDeckSF YearBuilt YearRemodAdd YrSold  1stFlrSF 2ndFlrSF  \
# 0     AllPub        140      1961         1961   2010       444       99
# 1     AllPub        140      1961         1961   2010       896        0
#
#   3SsnPorch
# 0       787
# 1         0
#
# [2 rows x 80 columns]

# %%
d = [{'Alley': None, 'BedroomAbvGr': 3, 'BldgType': '1Fam', 'BsmtCond': 'TA', 'BsmtExposure': 'No', 'BsmtFinSF1': 923, 'BsmtFinSF2': 0, 'BsmtFinType1': 'ALQ', 'BsmtFinType2': 'Unf', 'BsmtFullBath': 0, 'BsmtHalfBath': 0, 'BsmtQual': 'TA', 'BsmtUnfSF': 406, 'CentralAir': 'Y', 'Condition1': 'Norm', 'Condition2': 'Norm', 'Electrical': 'SBrkr', 'EnclosedPorch': 0, 'ExterCond': 'TA', 'ExterQual': 'TA', 'Exterior1st': 'Wd Sdng', 'Exterior2nd': 'Wd Sdng', 'Fence': None, 'FireplaceQu': None, 'Fireplaces': 0, 'Foundation': 'CBlock', 'FullBath': 1, 'Functional': 'Typ', 'GarageArea': 312, 'GarageCars': 1, 'GarageCond': 'TA', 'GarageFinish': 'Unf', 'GarageQual': 'TA', 'GarageType': 'Attchd', 'GarageYrBlt': 1958, 'GrLivArea': 1329, 'HalfBath': 1, 'Heating': 'GasA', 'HeatingQC': 'TA', 'HouseStyle': '1Story', 'Id': 1462, 'KitchenAbvGr': 1, 'KitchenQual': 'Gd', 'LandContour': 'Lvl', 'LandSlope': 'Gtl', 'LotArea': 14267, 'LotConfig': 'Corner', 'LotFrontage': 81, 'LotShape': 'IR1', 'LowQualFinSF': 0, 'MSSubClass': 20, 'MSZoning': 'RL', 'MasVnrArea': 108, 'MasVnrType': 'BrkFace', 'MiscFeature': 'Gar2', 'MiscVal': 12500, 'MoSold': 6, 'Neighborhood': 'NAmes', 'OpenPorchSF': 36, 'OverallCond': 6, 'OverallQual': 6, 'PavedDrive': 'Y', 'PoolArea': 0, 'PoolQC': None, 'RoofMatl': 'CompShg', 'RoofStyle': 'Hip', 'SaleCondition': 'Normal', 'SaleType': 'WD', 'ScreenPorch': 0, 'Street': 'Pave', 'TotRmsAbvGrd': 6, 'TotalBsmtSF': 1329, 'Utilities': 'AllPub', 'WoodDeckSF': 393, 'YearBuilt': 1958, 'YearRemodAdd': 1958, 'YrSold': 2010, '1stFlrSF': 1329, '2ndFlrSF': 0, '3SsnPorch': 0}, {'Alley': None, 'BedroomAbvGr': 3, 'BldgType': '1Fam', 'BsmtCond': 'TA', 'BsmtExposure': 'No', 'BsmtFinSF1': 791, 'BsmtFinSF2': 0, 'BsmtFinType1': 'GLQ', 'BsmtFinType2': 'Unf', 'BsmtFullBath': 0, 'BsmtHalfBath': 0, 'BsmtQual': 'Gd', 'BsmtUnfSF': 137, 'CentralAir': 'Y', 'Condition1': 'Norm', 'Condition2': 'Norm', 'Electrical': 'SBrkr', 'EnclosedPorch': 0, 'ExterCond': 'TA', 'ExterQual': 'TA', 'Exterior1st': 'VinylSd', 'Exterior2nd': 'VinylSd', 'Fence': 'MnPrv', 'FireplaceQu': 'TA', 'Fireplaces': 1, 'Foundation': 'PConc', 'FullBath': 2, 'Functional': 'Typ', 'GarageArea': 482, 'GarageCars': 2, 'GarageCond': 'TA', 'GarageFinish': 'Fin', 'GarageQual': 'TA', 'GarageType': 'Attchd', 'GarageYrBlt': 1997, 'GrLivArea': 1629, 'HalfBath': 1, 'Heating': 'GasA', 'HeatingQC': 'Gd', 'HouseStyle': '2Story', 'Id': 1463, 'KitchenAbvGr': 1, 'KitchenQual': 'TA', 'LandContour': 'Lvl', 'LandSlope': 'Gtl', 'LotArea': 13830, 'LotConfig': 'Inside', 'LotFrontage': 74, 'LotShape': 'IR1', 'LowQualFinSF': 0, 'MSSubClass': 60, 'MSZoning': 'RL', 'MasVnrArea': 0, 'MasVnrType': 'None', 'MiscFeature': None, 'MiscVal': 0, 'MoSold': 3, 'Neighborhood': 'Gilbert', 'OpenPorchSF': 34, 'OverallCond': 5, 'OverallQual': 5, 'PavedDrive': 'Y', 'PoolArea': 0, 'PoolQC': None, 'RoofMatl': 'CompShg', 'RoofStyle': 'Gable', 'SaleCondition': 'Normal', 'SaleType': 'WD', 'ScreenPorch': 0, 'Street': 'Pave', 'TotRmsAbvGrd': 6, 'TotalBsmtSF': 928, 'Utilities': 'AllPub', 'WoodDeckSF': 212, 'YearBuilt': 1997, 'YearRemodAdd': 1998, 'YrSold': 2010, '1stFlrSF': 928, '2ndFlrSF': 701, '3SsnPorch': 0}]

# %%
type(d)
# Out:
# list

# %%
type(d[0])
# Out:
# dict
